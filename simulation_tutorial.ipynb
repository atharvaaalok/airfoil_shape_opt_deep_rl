# %% [markdown]
# # Computing Aerodynamic Coefficients for an Airfoil using Xfoil

# %% [markdown]
# In this tutorial we see how to compute the lift-to-drag ratio of an airfoil at specified Mach and
# Reynolds numbers.

# %%
import math

import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

from src.cfd_utils.aerodynamics import compute_L_by_D

# %% [markdown]
# We perform out computations for the NACA0010.

# %%
airfoil_file_path = Path('./src/cfd_utils/airfoil_utils/naca0010.dat')
X = np.loadtxt(airfoil_file_path)

plt.plot(X[:, 0], X[:, 1])
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %% [markdown]
# Run Xfoil to compute the lift-to-drag ratio of our airfoil.

# %%
# Specify simulation parameters
M = 0.1
Re = 1e6
aoa = 5 * (math.pi / 180)

L_by_D = compute_L_by_D(X = X, M = M, Re = Re, aoa = aoa)

print(f'{L_by_D = }')
# Out:
# L_by_D = 63.79914718765357
